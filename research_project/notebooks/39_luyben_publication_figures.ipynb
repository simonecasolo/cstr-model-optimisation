# %% [markdown]
# # Notebook 39 -- Publication Figures (Luyben Section)
#
# Generates all Section 7 figures for the C&ChE paper at publication quality.
# Run after nb33, nb34, nb36, nb37 have been completed.
#
# Figure list:
# - Fig 7: SBC rank histograms (8 parameters)
# - Fig 8: Marginal posteriors 12 scenarios
# - Fig 9: Snowball time series + (alpha, eta_p) posterior + EKF overlay
# - Fig 10: 8×8 Fisher information heatmap
# - Fig 11: (alpha, eta_sep) banana curve vs EKF
# - Fig 12: 30-day tracking alpha, eta_sep with CI bands

# %%
import sys; sys.path.insert(0, '../src')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pickle
from pathlib import Path

from cstr_sbi.luyben.priors import PARAM_NAMES

# Publication style settings
mpl.rcParams.update({
    'font.size': 9,
    'axes.labelsize': 9,
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'figure.dpi': 300,
    'savefig.dpi': 300,
    'savefig.bbox': 'tight',
})

FIG_DIR = Path('../figures/luyben')
FIG_DIR.mkdir(parents=True, exist_ok=True)

# Check required results files
for fname in ['luyben_posterior.pkl']:
    p = Path(f'../results/{fname}')
    print(f'  {fname}: {"OK" if p.exists() else "MISSING -- run nb33 first"}')

# %% [markdown]
# ## Figure 7: SBC rank histograms

# %%
# TODO: populate from nb33 SBC results
# Load saved ranks array from nb33 and plot
# Placeholder -- runs after nb33 saves ranks
print('Run after nb33 has saved SBC ranks to ../results/luyben_sbc_ranks.npz')
# ranks = np.load('../results/luyben_sbc_ranks.npz')['ranks']  # (500, 8)
# fig, axes = plt.subplots(2, 4, figsize=(14/2.54, 7/2.54), constrained_layout=True)
# for j, (ax, pname) in enumerate(zip(axes.ravel(), PARAM_NAMES)):
#     ax.hist(ranks[:, j] / 1000.0, bins=20, density=True, alpha=0.8)
#     ax.axhline(1.0, ls='--', c='C1', lw=0.8)
#     ax.set_title(pname, fontsize=8)
# fig.savefig(FIG_DIR / 'fig07_sbc_ranks.pdf')

# %% [markdown]
# ## Figure 9: Snowball headline

# %%
# TODO: populate from nb34 / nb36 results
# Placeholder -- combine snowball time series + posterior pairplot + EKF ellipse
print('Run after nb34 and nb36 have been executed.')
# Full figure assembly code goes here.

# %% [markdown]
# ## Figure 12: 30-day tracking

# %%
# TODO: populate from nb37 results
# Load sbi_means, sbi_lo90, sbi_hi90, ekf_means, ekf_std, t_starts, theta_true_arr from nb37
print('Run after nb37 has been executed and results saved.')
